# %%
Cars = ("Lexus, Mercedes, BMW, Range Rover")
Car_Split = Cars.split("Lexus, Mercedes")
print(Car_Split)
print(Cars)
# Out:
# ['', ', BMW, Range Rover']
# Lexus, Mercedes, BMW, Range Rover

# %%
n = int(input("Enter your number"))

if (n %2 == 0):
        for i in range(n * 2):
            print(i)
        
else:
        print("n is a odd number")
# Out:
# Enter your number2
# 0
# 1
# 2
# 3
