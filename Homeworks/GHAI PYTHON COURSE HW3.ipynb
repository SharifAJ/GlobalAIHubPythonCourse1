# %%
print("Username : Python Beginner")
print("Password : P1TH1N")

user = input("Enter your Username")
password = input("Enter your Password")
    
if user == "Python Beginner":
    print("Your Username is Correct and Password is Wrong")
    
elif password == "P1TH1N":
    print("Your Password is Correct and Username is Wrong")
    
else:
    print("Username and Password is Incorrect")
# Out:
# Username : Python Beginner
# Password : P1TH1N
# Enter your UsernamePython Beginner
# Enter your PasswordP
# Your Username is Correct and Password is Wrong

# %%
Userdetails= {"Username":"Python Beginner","Password":"P1TH1N"}
print(Userdetails)


user = input("Enter your Username")
password = input("Enter your Password")
    
if user == "Python Beginner":
    print("Your Username is Correct and Password is Wrong")
    
elif password == "P1TH1N":
    print("Your Username is Wrong and Password is correct")
    
else:
    print("Username and Password is Incorrect")
# Out:
# {'Username': 'Python Beginner', 'Password': 'P1TH1N'}
# Enter your UsernameP
# Enter your PasswordP1TH1N
# Your Username is Wrong and Password is correct
